# %% [markdown]
# # General
# Template for labjournaal. See https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html for options to use markdown.
#
# **Name:**  Lucas Plasman
# **Title of the experiment:** Double pendulum with video
# **Starting date:** 22 September 2026
# **Expected enddate:**
# **Partner:** Isa
# **Goal of the experiment:**
# **Research question:**
# **Expectations or Hypothesis:**
# **Desired accuracy:**

# %%
#import necessary libraries
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.optimize import curve_fit

# %% [markdown]
# # Preparation

# %% [markdown]
# **Assignments:**

# %% [markdown]
# **Method:**
# **Theory:**
# **Independent variable:**
# **Dependent variable:**
# **Controlled variablen:**
# **Measurement instruments \& Settings:**
# **Procedure:**
# **Setup(drawing or picture):**
# **Notes:**
# **About accuracy:**

# %% [markdown]
# # Execution

# %%
# Measurements: Explain the names of variables provide only raw data in np.arrays!

#  Meeting van de parameters


# Length van de twee pendulum 
# Length and massa zijn gemeten op tablet 


# Method -> meten 10 keer met een hoek van 90°C ongeveer naar links 
# Meten 10 keer naar rechts 
# pixel per centimer 14.7431 -> afbeeling in picture measurement gedaan met reference grote blok

# %% [markdown]
# **Observations:**
# **Notes:**

# %% [markdown]
# # Processing
# **Description of processing of raw data into scientific evidence:**

# %%
#Data processing and analysis:

# %%
#Data processing and analysis:

# %%
#Data processing and analysis:

# %% [markdown]
# **Describing the pattern in the processed data:**

# %%
#Calculations of e.a. measurement uncertainties, and providing final answers.

# %% [markdown]
# **Notes:**

# %% [markdown]
# # Discussion

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Additional notes, remarks, explanations, thoughts etc
